# %% [markdown]
# <a href="https://colab.research.google.com/github/DmejiariUnal8313/Data-AnalitycsUN/blob/main/TallerPy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Taller Práctico Python # 1
# ## Analítica de Datos (Libre Elección)
# ***Nombres:***\
# **Daniel Felipe Mejia Rios**\
# **Santiago Mazo Orozco**\
# ***Profesor:***\
# ***Diego Fabian Collazos Huertas***
#
# *Administración de Sistemas Informáticos*\
# *Departamento de Informática y Computación* \
# *Universidad Nacional de Colombia - Sede Manizales*\
# *20 de Marzo de 2024*\
# *2024-I*
#
# --------------------------------

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import torch
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# ## **1.  Introducción  a Python y sus Ventajas**
#
# - ### **Python: Un lenguaje de programación versátil y de alto nivel.**
#
# *Python es un lenguaje de programación de alto nivel que ha ganado popularidad gracias a su enfoque en la legibilidad del código y su facilidad de uso. Con una sintaxis clara y concisa, Python permite a los programadores expresar conceptos de manera más intuitiva y rápida que con otros lenguajes. Además, su amplia comunidad de desarrolladores y la disponibilidad de una gran cantidad de bibliotecas y frameworks hacen que Python sea ideal para una variedad de aplicaciones, desde desarrollo web hasta análisis de datos y aprendizaje automático.*
#
#
# - ### **Ventajas de Python en análisis de datos y ciencia de datos: Potencia y facilidad de uso.**
#
# *Python se destaca en el ámbito del análisis de datos y la ciencia de datos debido a su combinación de potencia y facilidad de uso. Su sintaxis clara y intuitiva permite a los científicos de datos concentrarse en el análisis en lugar de luchar contra la complejidad del código. Además, Python cuenta con una amplia gama de bibliotecas especializadas como Pandas, NumPy y SciPy,Matplotlib,TensorFlow y PyTorch que simplifican tareas como la manipulación de datos, el cálculo numérico y la visualización de datos. Estas bibliotecas ofrecen funcionalidades avanzadas y eficientes, como el análisis estadístico, la generación de gráficos y la optimización de algoritmos.*
#
# - ### **Ecosistema de herramientas y bibliotecas populares para análisis de datos y ciencia de datos.**
#
# *El ecosistema de Python ofrece una integración fluida de herramientas y bibliotecas, lo que facilita un flujo de trabajo eficiente y centrado en temas específicos como el análisis de datos y la ciencia de datos.
#
# ***NumPy***: Es una biblioteca fundamental para el cálculo científico en Python. Permite operaciones matemáticas avanzadas y proporciona interfaces para trabajar con matrices multidimensionales, vectores y funciones matemáticas esenciales. Esto facilita el procesamiento eficiente de grandes conjuntos de datos y el desarrollo de algoritmos numéricos sofisticados.
#
# ***Pandas***: Diseñada específicamente para la manipulación y análisis de datos estructurados, Pandas ofrece herramientas poderosas para trabajar con series temporales, realizar la limpieza y preparación de datos, gestionar DataFrames, filtrar y agregar datos, así como visualizar datos en forma tabular. Su flexibilidad y facilidad de uso la convierten en una herramienta indispensable para cualquier proyecto de análisis de datos.
#
# ***Matplotlib***: Esta biblioteca es ampliamente utilizada para la creación de gráficos y visualización de datos en Python. Proporciona una variedad de opciones para generar una amplia gama de gráficos estáticos, desde simples diagramas de líneas hasta visualizaciones más complejas como gráficos de dispersión y histogramas. Matplotlib permite una personalización detallada de los gráficos para comunicar efectivamente la información contenida en los datos.
#
# Además de estas bibliotecas, en el entorno de análisis de datos y ciencia de datos también se destacan otras herramientas esenciales:
#
# ***SciPy***: Ofrece un conjunto de módulos y funciones para operaciones científicas avanzadas, incluyendo optimización, álgebra lineal, procesamiento de señales y estadísticas.
#
# ***TensorFlow y PyTorch***: Son bibliotecas líderes en el desarrollo de modelos de aprendizaje automático y análisis de datos a gran escala. Permiten la creación y entrenamiento de redes neuronales profundas, así como la implementación de algoritmos de aprendizaje automático para una variedad de aplicaciones, desde reconocimiento de imágenes hasta procesamiento del lenguaje natural.*
#
#
#
# ----------------
# ## **2. Google Colaboratory: ¿Qué es y por qué usarlo?**
#  ***Google Colaboratory***: Potenciando la colaboración y la eficiencia en el desarrollo de Python en la nube
# **Google Colaboratory**, conocido como Google Colab, es un entorno de desarrollo colaborativo basado en la nube proporcionado por Google. Permite ejecutar cuadernos interactivos de Python, conocidos como "notebooks", que contienen tanto celdas de texto explicativas como celdas de código ejecutable. Este entorno no utiliza recursos locales, sino que opera en línea y aprovecha los recursos asignados de una máquina virtual en la nube.
#
# - ### **Ventajas de usar Colab en comparación con entornos locales.**
#
# ***Acceso gratuito a GPUs de Google Cloud Platform***
#
# *Colab ofrece acceso gratuito a potentes unidades de procesamiento gráfico (GPUs) de Google Cloud Platform. Esto permite ejecutar código de manera más rápida y eficiente, especialmente en tareas intensivas en computación como el entrenamiento de modelos de aprendizaje automático o el procesamiento de grandes volúmenes de datos*.
#
# ***Almacenamiento en la nube***
#
# Los cuadernos de Colab se almacenan en la nube, lo que garantiza la seguridad y disponibilidad de los datos. Esto permite acceder y trabajar en los cuadernos desde cualquier lugar y dispositivo con conexión a Internet, sin preocuparse por la pérdida de datos o la sincronización de archivos*.
#
# ***Colaboración simplificada***
#
# Colab facilita la colaboración en proyectos al permitir compartir los cuadernos con otras personas. Esto facilita la revisión y la colaboración en tiempo real, lo que resulta en un flujo de trabajo más eficiente y colaborativo en comparación con los entornos locales donde compartir y sincronizar archivos puede ser más complicado*.
#
# ***Eficiencia en el trabajo en equipo***
#
# Al utilizar Colab, los equipos pueden trabajar de manera más eficiente en proyectos colaborativos. Todos los miembros del equipo pueden acceder y contribuir al mismo cuaderno simultáneamente, lo que facilita la comunicación y la coordinación en el desarrollo de proyectos complejos.
#
# ***Acceso a poderosas GPU de forma gratuita***
#
# Google Colab ofrece acceso a GPUs de alto rendimiento de forma gratuita. Algunas de las GPUs asignadas incluyen la Tesla T4, enfocada en análisis de datos; la Tesla V100, utilizada para redes neuronales; y la Tesla A100, ideal para el aprendizaje automático a gran escala. Esto permite ejecutar modelos complejos con un costo computacional reducido, lo que democratiza el acceso a herramientas avanzadas de procesamiento de datos y aprendizaje automático.*.
#
# --------
#
# ##  **3. Interfaz de Google Colab**
# ### **Explorando la Interfaz de Google Colab: Un entorno colaborativo en la nube**
#
# Google Colab proporciona una plataforma en la nube que facilita la colaboración y la ejecución de cuadernos interactivos de Python. Su interfaz ofrece una experiencia similar a los cuadernos de Jupyter, permitiendo a los usuarios trabajar con celdas de código y texto para desarrollar y documentar proyectos de manera colaborativa.
#
# **Gestión de cuadernos:**
#
# Crear un nuevo cuaderno en Google Colab es simple. Los usuarios pueden acceder a la plataforma y seleccionar "Nuevo cuaderno". Desde allí, pueden elegir dónde guardar el cuaderno, ya sea en Google Drive o en GitHub. Además, tienen la capacidad de cargar archivos adicionales, como imágenes o bases de datos, para su uso en el proyecto.
#
# ![Creación de un nuevo cuaderno](image.png)
#
# **Tipos de celdas: código y texto:**
#
# - **Celdas de código:** Estas celdas contienen scripts de Python que pueden ejecutarse de forma interactiva. Los resultados de las ejecuciones pueden mostrarse dentro del mismo cuaderno. Además, estas celdas pueden ser secuenciales, lo que significa que las variables y funciones definidas en una celda pueden ser utilizadas en celdas posteriores.
#
# ![Celdas de código](image-2.png)
#
# - **Celdas de texto (Markdown):** Estas celdas permiten la inserción de texto con formato, lo que incluye títulos, secciones, inserción de imágenes, enlaces y fórmulas matemáticas utilizando la sintaxis de LateX.
#
# ![Celdas de texto (Markdown)](image-3.png)
#
# - Google Colab ofrece una interfaz intuitiva y poderosa para el desarrollo colaborativo de proyectos de Python, promoviendo la eficiencia y la colaboración en entornos distribuidos.
# ---------
# ## **4. Trabajando con Datos en Notebooks**
# - ### **Importacion de bibliotecas: NumPy,Pandas, matplotlib (Arriba, primera sección).**

# %% [markdown]
# - ###  **Carga y manipulacion basica de datos.**

# %%
# Supongamos que estas son las mediciones de presión del agua durante una semana, en psi
presiones = np.array([30, 32, 31, 29, 30, 31, 33])

# Convertimos el array de NumPy en un DataFrame de Pandas
df_presiones = pd.DataFrame(presiones, columns=['Presión'])

# Añadimos una columna con los días de la semana
df_presiones['Día'] = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']

# Reordenamos las columnas
df_presiones = df_presiones[['Día', 'Presión']]

# Mostramos el DataFrame
print(df_presiones)

# Mostrar la información de las columnas del DataFrame
print(df_presiones.info())
# Out:
#          Día  Presión
# 0      Lunes       30
# 1     Martes       32
# 2  Miércoles       31
# 3     Jueves       29
# 4    Viernes       30
# 5     Sábado       31
# 6    Domingo       33
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Día      7 non-null      object
#  1   Presión  7 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 240.0+ bytes
# None

# %% [markdown]
# - ### **Visualizacion con Matplotlib.**

# %%
import matplotlib.pyplot as plt

# Asumiendo que ya tienes el DataFrame df_presiones como se definió anteriormente

# Graficamos las presiones a lo largo de la semana
plt.figure(figsize=(10, 5)) # Configuramos el tamaño del gráfico
plt.plot(df_presiones['Día'], df_presiones['Presión'], marker='o') # Creamos el gráfico de líneas

# Añadimos títulos y etiquetas
plt.title('Presión del Agua Durante la Semana')
plt.xlabel('Día de la Semana')
plt.ylabel('Presión (psi)')

# Añadimos una cuadrícula para mejor visualización
plt.grid(True)

# Mostramos el gráfico
plt.show()

# %% [markdown]
# ------------------

# %% [markdown]
# ## **5. Ejemplo de Analisis de Datos**
# - ### **Realización de un análisis simple utilizando los datos cargados.**

# %% [markdown]
# - ### **Generacion de graficos descriptivos.**

# %%
import seaborn as sns

# Cargamos el dataset
df = pd.read_csv('2022-11-21 World Cup teams by country past week.csv')

# Mostramos las primeras filas del dataframe para verificar su contenido
print(df.head())

# Contamos la frecuencia con la que cada equipo aparece como 'Top searched'
conteo_equipos = df['Top searched'].value_counts()

# Gráfico de Barras de Frecuencia
plt.figure(figsize=(10, 5))
conteo_equipos.plot(kind='bar', color='skyblue')
plt.title('Frecuencia de Equipos Más Buscados')
plt.xlabel('Equipo')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Creamos una tabla de contingencia para el mapa de calor
tabla_contingencia = pd.crosstab(df['Country'], df['Top searched'])

# Mapa de Calor
plt.figure(figsize=(12, 8))
sns.heatmap(tabla_contingencia, annot=False, cmap='coolwarm')
plt.title('Mapa de Calor de Búsquedas por País y Equipo')
plt.xlabel('Equipo')
plt.ylabel('País')
plt.show()
# Out:
#           Country Top searched     Second      Third    Fourth     Fifth
# 0     Afghanistan        Qatar  Argentina    Ecuador  Portugal      Iran
# 1   Åland Islands      Morocco   Portugal      Qatar   Belgium   England
# 2         Albania        Qatar    Ecuador  Argentina    Brazil  Portugal
# 3         Algeria        Qatar  Argentina    Ecuador  Portugal   Morocco
# 4  American Samoa    Australia      Qatar    England  Portugal   Denmark

# %% [markdown]
# ------
#
#  ### **Interpretacion de resultados**
#
#
# #### ***Diagrama de Frecuencia***
#
# *El diagrama de barras de frecuencia muestra cuántas veces cada equipo aparece como el más buscado en el conjunto de datos. Un equipo con una barra más alta indica que ha generado más interés de búsqueda en comparación con los demás. Esto puede reflejar su popularidad o relevancia durante el período de tiempo específico del dataset. Por ejemplo, si un equipo tiene una barra significativamente más alta que los demás, podría sugerir que tuvo un desempeño destacado en la Copa Mundial o que estuvo involucrado en eventos que captaron la atención del público.*
#
# #### ***Mapa de Calor***
#
# *El mapa de calor proporciona una representación visual de la relación entre dos variables categóricas: los países y los equipos más buscados. En este caso, los colores más cálidos (como el rojo) indican una mayor frecuencia de búsquedas de un equipo específico en un país, mientras que los colores más fríos (como el azul) indican una menor frecuencia. Este gráfico puede ayudar a identificar patrones geográficos en el interés de búsqueda, como qué equipos son populares en qué regiones o si hay algún equipo que destaque globalmente en términos de interés de búsqueda.*
#
# *Ambos gráficos juntos pueden ofrecer una visión comprensiva de la dinámica de interés durante la Copa Mundial, mostrando tanto la popularidad general de los equipos como su distribución geográfica de interés.*
#
#
# ---------
